# %% [markdown]
# # PyTorch Training and using checkpointing on SageMaker Managed Spot Training
# The example here is almost the same as [PyTorch Cifar10 local training](https://github.com/aws/amazon-sagemaker-examples/blob/master/sagemaker-python-sdk/pytorch_cnn_cifar10/pytorch_local_mode_cifar10.ipynb).
#
# This notebook tackles the exact same problem with the same solution, but it has been modified to be able to run using SageMaker Managed Spot infrastructure. SageMaker Managed Spot uses [EC2 Spot Instances](https://aws.amazon.com/ec2/spot/) to run Training at a lower cost.
#
# Please read the original notebook and try it out to gain an understanding of the ML use-case and how it is being solved. We will not delve into that here in this notebook.

# %%
# base_job_name = 'Select-Turn/PPTOD-base-Random/mwz20'
# base_job_name = 'Select-Turn/PPTOD-base-MaxEntropy/mwz20'
base_job_name = 'Select-Turn/PPTOD-base-LeastConfidence/mwz20'

# base_job_name = 'Train/PPTOD-base-LastTurn/mwz20'
# base_job_name = 'Train/PPTOD-base-Random/mwz20'

# %%
import sagemaker
import uuid
import random

sagemaker_session = sagemaker.Session()
print('SageMaker version: ' + sagemaker.__version__)

# bucket = sagemaker_session.default_bucket()
bucket = 'prod-tpgt-knowledge-lake-sandpit-v1'
prefix = 'zihan-research/dialogue-state-tracking/PPTOD-AL'

role = sagemaker.get_execution_role()
# checkpoint_suffix = str(uuid.uuid4())[:8]
checkpoint_s3_path = f's3://{bucket}/{prefix}/{base_job_name}/checkpoints'
# checkpoint_s3_path = 's3://{}/checkpoint-{}'.format(bucket, checkpoint_suffix)

print('Checkpointing Path: {}'.format(checkpoint_s3_path))
# Out:
# SageMaker version: 2.86.2
# Checkpointing Path: s3://prod-tpgt-knowledge-lake-sandpit-v1/zihan-research/dialogue-state-tracking/PPTOD-AL/Select-Turn/PPTOD-base-LeastConfidence/mwz20/checkpoints

# %%
# specify the path to store the model outputs in S3
output_path = f's3://{bucket}/{prefix}/{base_job_name}/model'
output_path
# Out:
# 's3://prod-tpgt-knowledge-lake-sandpit-v1/zihan-research/dialogue-state-tracking/PPTOD-AL/Select-Turn/PPTOD-base-LeastConfidence/mwz20/model'

# %%
# specify the path to store the source code in S3
code_location = f's3://{bucket}/{prefix}/{base_job_name}/source_code'
code_location
# Out:
# 's3://prod-tpgt-knowledge-lake-sandpit-v1/zihan-research/dialogue-state-tracking/PPTOD-AL/Select-Turn/PPTOD-base-LeastConfidence/mwz20/source_code'

# %%
# tensorboard_s3_path = f's3://{bucket}/{prefix}/{base_job_name}/tensorboard'
# tensorboard_s3_path

# %%
# train_data_path = f's3://{bucket}/{prefix}/Data/MultiWOZ/dst/train_v2.0.json'
# train_data_path

# %%
# validation_data_path = f's3://{bucket}/{prefix}/Data/MultiWOZ/dst/dev_v2.0.json'
# validation_data_path

# %%
# test_data_path = f's3://{bucket}/{prefix}/Data/MultiWOZ/dst/test_v2.0.json'
# test_data_path

# %%
# import os
# import subprocess

# instance_type = 'local'

# if subprocess.call('nvidia-smi') == 0:
#     ## Set type to GPU if one is present
#     instance_type = 'local_gpu'
    
# print("Instance type = " + instance_type)

# %% [markdown]
# ### Upload the data
# We use the ```sagemaker.Session.upload_data``` function to upload our datasets to an S3 location. The return value inputs identifies the location -- we will use this later when we start the training job.

# %%
# sagemaker_session.upload_data(path='data/multiwoz/data/multi-woz-fine-processed', bucket=bucket, key_prefix=f'{prefix}/Data/MWZ20')

# %% [markdown]
# ## Create a training job using the sagemaker.PyTorch estimator
#
# The `PyTorch` class allows us to run our training function on SageMaker. We need to configure it with our training script, an IAM role, the number of training instances, and the training instance type. For local training with GPU, we could set this to "local_gpu".  In this case, `instance_type` was set above based on your whether you're running a GPU instance.
#
# After we've constructed our `PyTorch` object, we fit it using the data we uploaded to S3. Even though we're in local mode, using S3 as our data source makes sense because it maintains consistency with how SageMaker's distributed, managed training ingests data.

# %%
# inputs = {
#     'train': train_data_path,
#     'validation': validation_data_path,
#     'test': test_data_path
# }

# copy all content in the 'Data' folder from S3 to local
inputs = f's3://{bucket}/{prefix}/Data/MWZ20'
inputs
# Out:
# 's3://prod-tpgt-knowledge-lake-sandpit-v1/zihan-research/dialogue-state-tracking/PPTOD-AL/Data/MWZ20'

# %%
# hyperparameters = {
#     'config': './configs/KAGE_GPT2_SparseSupervision.jsonnet',
#     'mode': 'train',
#     'experiment_name': 'KAGE-DS-L4P4K2-LastTurn-RandomTurn',
#     'num_layer': 4,
#     'num_head': 4,
#     'num_hop': 2,
#     'graph_mode': 'part',
# #     'only_last_turn': True,
# #     'dummy_dataloader': True
# }

# %%
# !df -h

# %%
# ecr_image = '763104351884.dkr.ecr.ap-southeast-2.amazonaws.com/pytorch-training:1.6.0-gpu-py36-cu110-ubuntu16.04'

# %%
# from sagemaker.pytorch import PyTorch
# from sagemaker.debugger import TensorBoardOutputConfig

# # hyperparameters = {'epochs': 2}

# tensorboard_output_config = TensorBoardOutputConfig(
#     s3_output_path=tensorboard_s3_path,
#     container_local_output_path='/opt/ml/output/tensorboard'
# )

# cifar10_estimator = PyTorch(entry_point='main.py',
#                             source_dir='Src',
#                             output_path=output_path,
#                             code_location=code_location,
#                             role=role,
#                             image_uri=ecr_image,
# #                             framework_version='1.6',
# #                             py_version='py3',
# #                             volume_size=256,
#                             hyperparameters=hyperparameters,
#                             instance_count=1,
#                             instance_type=instance_type,
#                             base_job_name=base_job_name,
#                             tensorboard_output_config=tensorboard_output_config
#                            )

# cifar10_estimator.fit(inputs)

# %% [markdown]
# ## Run a baseline training job on SageMaker
#
# Now we run training jobs on SageMaker, starting with our baseline training job.
#
# Once again, we create a PyTorch estimator, with a couple key modfications from last time:
#
# * `instance_type`: the instance type for training. We set this to `ml.p3.2xlarge` because we are training on SageMaker now. For a list of available instance types, see [the AWS documentation](https://aws.amazon.com/sagemaker/pricing/instance-types).
# * `metric_definitions`: the metrics (defined above) that we want sent to CloudWatch.

# %%
use_spot_instances = True
max_run = 120 * 60 * 60 # max run time is 120hours
# max_run = 240 * 60 * 60 # max run time is 120hours
max_wait = 90000 if use_spot_instances else None # max waiting 20mins

# %%
ecr_image = '763104351884.dkr.ecr.ap-southeast-2.amazonaws.com/pytorch-training:1.6.0-gpu-py36-cu110-ubuntu16.04'
# ecr_image = '763104351884.dkr.ecr.ap-southeast-2.amazonaws.com/pytorch-training:1.7.1-gpu-py36-cu110-ubuntu18.04'

# %%
from sagemaker.pytorch import PyTorch
from sagemaker.debugger import TensorBoardOutputConfig


# tensorboard_output_config = TensorBoardOutputConfig(
#     s3_output_path=tensorboard_s3_path,
#     container_local_output_path='/opt/ml/output/tensorboard'
# )

random_seed = random.randint(0, 999)
print(random_seed)

hyperparameters = {
    'model_name': 't5-base',
    'gradient_accumulation_steps': 4,
    'number_of_gpu': 1,
    'batch_size_per_gpu': 2,
    'train_data_ratio': 1.0,
    'random_seed': random_seed,
    
#     'acquisition': 'random',
    'acquisition': 'least_confidence',
#     'acquisition': 'max_entropy',
    
    'num_dialogue_per_round': 100,
    'pre_selected_turn_path': './S123_selected_turn_id.csv',
    
    'patience': 3,
    'epoch_num': 50,
    
    'only_last_turn': 'False',
    'only_random_turn': 'False',
    'data_path_prefix': './mwz_data/mwz20/multi-woz-fine-processed/', # MWZ2.0
    'pretrained_path': './pretrained_pptod/base',
    'ckpt_save_path': f'/opt/ml/model',
    
    
#     'config': './configs/KAGE_GPT2_SparseSupervision.jsonnet',
#     'mode': 'train',
#     'selected_turn_path': './selected_turns/selected_turn_id.csv', # csv file path
    
    # only for continue training
#     'continue_select_turn': 1,
#     'selected_turn_path': './selected_turns', # folder contains selected_turn_id.csv, model_best.pth.tar, tokenizer/
    
#     'config': './configs/KAGE_GPT2_FullTraining.jsonnet',
#     'mode': 'select_turn',
#     'budget': 0,
#     'budget_random_turn': 0, # use 0 as the last turn to train
#     'budget_epoch': 5,
#     'round_epoch': 150, # for each round, train 80 epochs and apply early stop
    
#     'acquisition': 'random',
# #     'acquisition': 'last_turn',
# #     'acquisition': 'least_confidence',
# #     'acquisition': 'max_entropy',
    
#     ###### Remeber to go to main.py to change "--only_last_turn" to False !!!
    
#     'experiment_name': base_job_name,
#     'num_layer': 4,
#     'num_head': 4,
#     'num_hop': 2,
#     'graph_mode': 'part',
#     'random_seed': random_seed
}

environment = {
    'ENV': 'sagemaker_training_job'
}

# metric_definitions = [
#     {
#         'Name': 'epoch',
#         'Regex': 'epoch (.*?) - '
#     },
#     {
#         'Name': 'train_loss',
#         'Regex': 'train loss (.*?)='
#     },
#     {
#         'Name': 'valid_joint_acc',
#         'Regex': 'joint_acc: (.*?) '
#     },
#     {
#         'Name': 'valid_slot_acc',
#         'Regex': 'slot_acc: (.*?) '
#     },
#     {
#         'Name': 'test_joint_acc',
#         'Regex': 'test joint_acc: (.*?) '
#     }
# ]

estimator = PyTorch(
#     entry_point='learn.py',
    
    entry_point='active_learn.py',
    
    source_dir='DST',
    output_path=output_path,
    code_location=code_location,
    role=role,
    image_uri=ecr_image,
#                             framework_version='1.6',
#                             py_version='py3',
    hyperparameters=hyperparameters,
    instance_count=1,
    instance_type='ml.g4dn.xlarge', 
#                             instance_type='ml.p3.2xlarge', # V100
#                             instance_type='ml.p3.2xlarge',

#                             base_job_name=f'Debug-train500-S{random_seed}',
#                             base_job_name=f'Rand-B24D2000Bud0-S{random_seed}',
    
#     base_job_name=f'PPTOD-MWZ20-ME-D100-S{random_seed}',
#     base_job_name=f'PPTOD-MWZ20-Rand-D100-S{random_seed}',
    base_job_name=f'PPTOD-MWZ20-LC-D100-S{random_seed}',
    
#     base_job_name=f'PPTOD-MWZ20-Rand-B24D2000Bud0-S{random_seed}',
#     base_job_name=f'PPTOD-MWZ20-LC-B24D2000Bud0-S{random_seed}',
#     base_job_name=f'PPTOD-MWZ20-ME-B24D2000Bud0-S{random_seed}',
    
#                             base_job_name=f'Train-PPTOD-base-Rand-S{random_seed}',

#                             base_job_name=f'Train-KAGE-LT-MWZ21-S{random_seed}',
    # base_job_name=f'Train-B16D2000Bud0-S{random_seed}',


    # spot training settings: Remember also to set use_spot_instances=True in main.py
#                             checkpoint_s3_uri=checkpoint_s3_path,
    debugger_hook_config=False,
#                             use_spot_instances=use_spot_instances,
    max_run=max_run, # if not set, default is 86400=24h
#                             max_wait=max_wait,
#                             volume_size=225,
    volume_size=125,
    # tensorboard setting
#                             tensorboard_output_config=tensorboard_output_config,
#                             metric_definitions=metric_definitions,
    environment=environment
   )

# estimator.fit(inputs)
estimator.fit()
# Out:
# 43
# 2022-06-19 01:22:56 Starting - Starting the training job...
# 2022-06-19 01:23:20 Starting - Preparing the instances for trainingProfilerReport-1655601776: InProgress
# ......
# 2022-06-19 01:24:21 Downloading - Downloading input data...
# 2022-06-19 01:24:41 Training - Downloading the training image..................
# 2022-06-19 01:27:42 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-06-19 01:27:44,952 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-06-19 01:27:44,974 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-06-19 01:27:44,983 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-06-19 01:29:24,823 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /opt/conda/bin/python -m pip install -r requirements.txt
# Collecting absl-py
#   Downloading absl_py-1.1.0-py3-none-any.whl (123 kB)
# Collecting pytest
#   Downloading pytest-7.0.1-py3-none-any.whl (296 kB)
# Collecting sacrebleu==1.4.10
#   Downloading sacrebleu-1.4.10-py3-none-any.whl (60 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 5)) (0.35.1)
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: torch==1.6.0 in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 8)) (1.6.0)
# Collecting torchvision==0.7.0
#   Downloading torchvision-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (5.9 MB)
# Collecting transformers==4.7.0
#   Downloading transformers-4.7.0-py3-none-any.whl (2.5 MB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 11)) (5.3.1)
# Collecting nltk
#   Downloading nltk-3.6.7-py3-none-any.whl (1.5 MB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Requirement already satisfied: spacy in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 14)) (2.3.2)
# Collecting gdown
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 16)) (1.1.3)
# Collecting attrs>=19.2.0
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.6/site-packages (from pytest->-r requirements.txt (line 2)) (20.4)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /opt/conda/lib/python3.6/site-packages (from pytest->-r requirements.txt (line 2)) (2.0.0)
# Collecting tomli>=1.0.0
#   Downloading tomli-1.2.3-py3-none-any.whl (12 kB)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.6/site-packages (from sklearn->-r requirements.txt (line 7)) (0.23.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.6/site-packages (from torch==1.6.0->-r requirements.txt (line 8)) (0.18.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from torch==1.6.0->-r requirements.txt (line 8)) (1.19.1)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.6/site-packages (from torchvision==0.7.0->-r requirements.txt (line 9)) (8.0.1)
# Collecting filelock
#   Downloading filelock-3.4.1-py3-none-any.whl (9.9 kB)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /opt/conda/lib/python3.6/site-packages (from transformers==4.7.0->-r requirements.txt (line 10)) (0.7)
# Collecting regex!=2019.12.17
#   Downloading regex-2022.6.2-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (749 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from transformers==4.7.0->-r requirements.txt (line 10)) (2.24.0)
# Collecting huggingface-hub==0.0.8
#   Downloading huggingface_hub-0.0.8-py3-none-any.whl (34 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.6/site-packages (from transformers==4.7.0->-r requirements.txt (line 10)) (4.46.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.6/site-packages (from nltk->-r requirements.txt (line 12)) (0.17.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.6/site-packages (from nltk->-r requirements.txt (line 12)) (7.1.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (0.8.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (1.0.4)
# Requirement already satisfied: thinc==7.4.1 in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (7.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (1.0.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (50.3.0.post20201006)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (2.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from spacy->-r requirements.txt (line 14)) (3.0.4)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.6/site-packages (from gdown->-r requirements.txt (line 15)) (4.9.3)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas->-r requirements.txt (line 16)) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.6/site-packages (from pandas->-r requirements.txt (line 16)) (2.8.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->pytest->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest->-r requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.6/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 7)) (1.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.7.0->-r requirements.txt (line 10)) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.7.0->-r requirements.txt (line 10)) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.7.0->-r requirements.txt (line 10)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.7.0->-r requirements.txt (line 10)) (1.25.11)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /opt/conda/lib/python3.6/site-packages (from beautifulsoup4->gdown->-r requirements.txt (line 15)) (2.0.1)
# Building wheels for collected packages: progressbar, sklearn, gdown, sacremoses
#   Building wheel for progressbar (setup.py): started
#   Building wheel for progressbar (setup.py): finished with status 'done'
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12074 sha256=50a058aa3e3e081e90b0bc9092fba46b60abeaffa97e4adeef4d68963dcadc08
#   Stored in directory: /root/.cache/pip/wheels/bc/13/93/a9bf6b3d3966e4af014b0dbef027fdea47393faf47e990349f
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=c88fea8ca06698f68e84f28d9551bb59ae94cc9707a7b3f7e20f8f719312b3ac
#   Stored in directory: /root/.cache/pip/wheels/23/9d/42/5ec745cbbb17517000a53cecc49d6a865450d1f5cb16dc8a9c
#   Building wheel for gdown (PEP 517): started
#   Building wheel for gdown (PEP 517): finished with status 'done'
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14774 sha256=55d186ba7d9c1ae55448339c91d32e58f4a4e0e5ad575ddbf67f145a15a14e55
#   Stored in directory: /root/.cache/pip/wheels/96/f9/d3/4594b3b2fe2ee239d0c9eb861f468204652e0a1c6d03755d75
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895252 sha256=59850718dfbf1e7288d14b659d0e1d138b16de2aba52c35c0df852cae31a54e0
#   Stored in directory: /root/.cache/pip/wheels/4c/64/31/e9900a234b23fb3e9dc565d6114a9d6ff84a72dbdd356502b4
# Successfully built progressbar sklearn gdown sacremoses
# Installing collected packages: absl-py, attrs, py, pluggy, iniconfig, tomli, pytest, portalocker, sacrebleu, progressbar, sklearn, torchvision, filelock, tokenizers, regex, huggingface-hub, sacremoses, transformers, nltk, sentencepiece, gdown
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.7.0a0+78ed10c
#     Uninstalling torchvision-0.7.0a0+78ed10c:
#       Successfully uninstalled torchvision-0.7.0a0+78ed10c
# Successfully installed absl-py-1.1.0 attrs-21.4.0 filelock-3.4.1 gdown-4.4.0 huggingface-hub-0.0.8 iniconfig-1.1.1 nltk-3.6.7 pluggy-1.0.0 portalocker-2.4.0 progressbar-2.5 py-1.11.0 pytest-7.0.1 regex-2022.6.2 sacrebleu-1.4.10 sacremoses-0.0.53 sentencepiece-0.1.96 sklearn-0.0 tokenizers-0.10.3 tomli-1.2.3 torchvision-0.7.0 transformers-4.7.0
# 2022-06-19 01:29:40,936 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "acquisition": "least_confidence",
#         "batch_size_per_gpu": 2,
#         "ckpt_save_path": "/opt/ml/model",
#         "data_path_prefix": "./mwz_data/mwz20/multi-woz-fine-processed/",
#         "epoch_num": 50,
#         "gradient_accumulation_steps": 4,
#         "model_name": "t5-base",
#         "num_dialogue_per_round": 100,
#         "number_of_gpu": 1,
#         "only_last_turn": "False",
#         "only_random_turn": "False",
#         "patience": 3,
#         "pre_selected_turn_path": "./S123_selected_turn_id.csv",
#         "pretrained_path": "./pretrained_pptod/base",
#         "random_seed": 43,
#         "train_data_ratio": 1.0
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "PPTOD-MWZ20-LC-D100-S43-2022-06-19-00-53-11-095",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://prod-tpgt-knowledge-lake-sandpit-v1/zihan-research/dialogue-state-tracking/PPTOD-AL/Select-Turn/PPTOD-base-LeastConfidence/mwz20/source_code/PPTOD-MWZ20-LC-D100-S43-2022-06-19-00-53-11-095/source/sourcedir.tar.gz",
#     "module_name": "active_learn",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "active_learn.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"acquisition":"least_confidence","batch_size_per_gpu":2,"ckpt_save_path":"/opt/ml/model","data_path_prefix":"./mwz_data/mwz20/multi-woz-fine-processed/","epoch_num":50,"gradient_accumulation_steps":4,"model_name":"t5-base","num_dialogue_per_round":100,"number_of_gpu":1,"only_last_turn":"False","only_random_turn":"False","patience":3,"pre_selected_turn_path":"./S123_selected_turn_id.csv","pretrained_path":"./pretrained_pptod/base","random_seed":43,"train_data_ratio":1.0}
# SM_USER_ENTRY_POINT=active_learn.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=active_learn
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://prod-tpgt-knowledge-lake-sandpit-v1/zihan-research/dialogue-state-tracking/PPTOD-AL/Select-Turn/PPTOD-base-LeastConfidence/mwz20/source_code/PPTOD-MWZ20-LC-D100-S43-2022-06-19-00-53-11-095/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"acquisition":"least_confidence","batch_size_per_gpu":2,"ckpt_save_path":"/opt/ml/model","data_path_prefix":"./mwz_data/mwz20/multi-woz-fine-processed/","epoch_num":50,"gradient_accumulation_steps":4,"model_name":"t5-base","num_dialogue_per_round":100,"number_of_gpu":1,"only_last_turn":"False","only_random_turn":"False","patience":3,"pre_selected_turn_path":"./S123_selected_turn_id.csv","pretrained_path":"./pretrained_pptod/base","random_seed":43,"train_data_ratio":1.0},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"PPTOD-MWZ20-LC-D100-S43-2022-06-19-00-53-11-095","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://prod-tpgt-knowledge-lake-sandpit-v1/zihan-research/dialogue-state-tracking/PPTOD-AL/Select-Turn/PPTOD-base-LeastConfidence/mwz20/source_code/PPTOD-MWZ20-LC-D100-S43-2022-06-19-00-53-11-095/source/sourcedir.tar.gz","module_name":"active_learn","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"active_learn.py"}
# SM_USER_ARGS=["--acquisition","least_confidence","--batch_size_per_gpu","2","--ckpt_save_path","/opt/ml/model","--data_path_prefix","./mwz_data/mwz20/multi-woz-fine-processed/","--epoch_num","50","--gradient_accumulation_steps","4","--model_name","t5-base","--num_dialogue_per_round","100","--number_of_gpu","1","--only_last_turn","False","--only_random_turn","False","--patience","3","--pre_selected_turn_path","./S123_selected_turn_id.csv","--pretrained_path","./pretrained_pptod/base","--random_seed","43","--train_data_ratio","1.0"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_ACQUISITION=least_confidence
# SM_HP_BATCH_SIZE_PER_GPU=2
# SM_HP_CKPT_SAVE_PATH=/opt/ml/model
# SM_HP_DATA_PATH_PREFIX=./mwz_data/mwz20/multi-woz-fine-processed/
# SM_HP_EPOCH_NUM=50
# SM_HP_GRADIENT_ACCUMULATION_STEPS=4
# SM_HP_MODEL_NAME=t5-base
# SM_HP_NUM_DIALOGUE_PER_ROUND=100
# SM_HP_NUMBER_OF_GPU=1
# SM_HP_ONLY_LAST_TURN=False
# SM_HP_ONLY_RANDOM_TURN=False
# SM_HP_PATIENCE=3
# SM_HP_PRE_SELECTED_TURN_PATH=./S123_selected_turn_id.csv
# SM_HP_PRETRAINED_PATH=./pretrained_pptod/base
# SM_HP_RANDOM_SEED=43
# SM_HP_TRAIN_DATA_RATIO=1.0
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python active_learn.py --acquisition least_confidence --batch_size_per_gpu 2 --ckpt_save_path /opt/ml/model --data_path_prefix ./mwz_data/mwz20/multi-woz-fine-processed/ --epoch_num 50 --gradient_accumulation_steps 4 --model_name t5-base --num_dialogue_per_round 100 --number_of_gpu 1 --only_last_turn False --only_random_turn False --patience 3 --pre_selected_turn_path ./S123_selected_turn_id.csv --pretrained_path ./pretrained_pptod/base --random_seed 43 --train_data_ratio 1.0
# Cuda is available.
# Using single GPU training.
# Ramdom seed: 43
# Acquisition method: least_confidence
# Start loading data...
# Loading Pretrained Tokenizer...
# pre_selected_turn_ids: 500 ['SNG0596-4', 'PMUL4585-5', 'PMUL1873-11', 'SNG0300-4', 'MUL2095-8', 'MUL2297-6', 'MUL1990-7', 'PMUL1475-3', 'PMUL3033-6', 'PMUL3513-13', 'PMUL4745-6', 'PMUL0964-7', 'MUL0399-8', 'PMUL0824-7', 'PMUL1767-7', 'SSNG0185-3', 'MUL0766-6', 'PMUL2987-9', 'SNG0731-2', 'SNG0802-4', 'MUL0122-7', 'PMUL1527-6', 'MUL0802-7', 'PMUL0971-2', 'SNG01712-3', 'PMUL4342-3', 'PMUL1567-7', 'WOZ20358-3', 'PMUL1746-6', 'PMUL4096-8', 'SNG0540-3', 'MUL1404-7', 'PMUL1913-7', 'PMUL0478-7', 'MUL1229-8', 'MUL2636-9', 'SNG0562-2', 'MUL0101-8', 'PMUL0800-7', 'PMUL0354-9', 'MUL2272-8', 'PMUL2451-9', 'SNG0504-3', 'SNG1299-0', 'PMUL0722-4', 'PMUL3881-5', 'PMUL3863-13', 'SNG0707-3', 'MUL2691-11', 'SNG0453-2', 'MUL0969-6', 'SNG01294-2', 'MUL1473-5', 'WOZ20645-1', 'PMUL3385-2', 'SNG1281-3', 'PMUL1381-8', 'SNG0574-5', 'PMUL4117-5', 'MUL2109-5', 'PMUL4477-3', 'WOZ20169-3', 'MUL0277-5', 'PMUL0126-8', 'PMUL2760-14', 'SNG02103-3', 'PMUL3316-9', 'MUL0028-7', 'PMUL1010-7', 'MUL0015-8', 'SNG1151-2', 'MUL0195-9', 'PMUL2291-8', 'MUL2561-7', 'SSNG0348-4', 'SSNG0171-1', 'MUL0327-12', 'PMUL2672-6', 'WOZ20638-3', 'WOZ20206-2', 'SSNG0169-1', 'MUL2182-5', 'PMUL2281-8', 'WOZ20246-2', 'SNG01862-1', 'MUL0284-6', 'PMUL1646-10', 'PMUL2524-4', 'PMUL4917-9', 'MUL1499-7', 'MUL2611-5', 'MUL1785-6', 'PMUL1989-8', 'PMUL4653-6', 'PMUL0437-8', 'WOZ20587-2', 'SNG1104-4', 'PMUL3155-8', 'PMUL2349-7', 'PMUL4774-6', 'MUL0254-7', 'PMUL1487-7', 'PMUL4528-6', 'PMUL0981-6', 'SSNG0058-3', 'MUL2485-7', 'SNG0499-3', 'PMUL4412-7', 'PMUL2752-8', 'MUL0919-6', 'PMUL2501-6', 'PMUL0305-7', 'PMUL1703-9', 'MUL1439-6', 'PMUL4954-6', 'WOZ20046-4', 'PMUL0101-9', 'PMUL0050-8', 'SNG02248-2', 'PMUL0395-10', 'PMUL1161-8', 'PMUL2808-10', 'PMUL3538-6', 'PMUL1489-7', 'PMUL0502-9', 'WOZ20377-2', 'MUL0560-7', 'MUL1052-8', 'MUL2050-11', 'SNG0262-4', 'MUL0550-6', 'MUL1054-5', 'PMUL3058-4', 'PMUL0373-11', 'PMUL0150-8', 'PMUL2709-7', 'MUL1717-6', 'MUL2472-4', 'PMUL1349-4', 'MUL2033-8', 'PMUL3154-9', 'SNG0878-5', 'PMUL2387-6', 'WOZ20667-3', 'PMUL0834-6', 'PMUL3343-2', 'MUL1949-4', 'WOZ20648-2', 'PMUL3566-10', 'PMUL2583-10', 'SSNG0082-8', 'PMUL1855-8', 'PMUL4508-4', 'SSNG0372-7', 'MUL1524-7', 'MUL1593-8', 'MUL0192-7', 'PMUL2814-9', 'WOZ20519-2', 'SNG0639-4', 'SSNG0005-5', 'SNG02106-5', 'MUL0497-6', 'PMUL1634-8', 'MUL1498-10', 'PMUL1287-5', 'MUL1216-9', 'SSNG0197-3', 'PMUL2356-3', 'MUL2308-7', 'PMUL0459-2', 'PMUL1702-7', 'PMUL0808-7', 'SSNG0358-6', 'PMUL4822-7', 'SSNG0048-3', 'SNG0488-3', 'MUL0318-7', 'SNG0025-3', 'SSNG0374-3', 'MUL0925-6', 'MUL1962-5', 'PMUL2110-8', 'SSNG0317-5', 'MUL0521-6', 'PMUL3877-3', 'SNG1103-4', 'PMUL0151-6', 'PMUL3671-8', 'SNG01339-5', 'MUL1086-7', 'SNG1264-3', 'PMUL0324-9', 'PMUL1404-3', 'MUL0263-8', 'SNG1217-4', 'MUL2336-7', 'PMUL2523-7', 'MUL1236-10', 'PMUL1024-6', 'PMUL1204-7', 'PMUL2099-6', 'PMUL4961-7', 'PMUL2684-10', 'MUL2094-6', 'PMUL0885-4', 'WOZ20189-3', 'PMUL4105-9', 'SNG1168-4', 'PMUL2978-6', 'PMUL0131-9', 'MUL1170-5', 'PMUL2203-6', 'PMUL0316-7', 'MUL0592-6', 'PMUL4887-4', 'SSNG0009-4', 'PMUL0939-6', 'PMUL3609-5', 'PMUL3771-4', 'PMUL3616-7', 'MUL0184-10', 'SNG1332-3', 'PMUL1643-7', 'MUL1038-11', 'MUL1063-7', 'SNG01697-3', 'SNG0976-4', 'PMUL0842-8', 'PMUL3102-7', 'PMUL3757-8', 'MUL0611-9', 'MUL0066-8', 'PMUL4135-8', 'PMUL1315-6', 'SSNG0389-3', 'PMUL4991-8', 'SNG0559-4', 'MUL2371-4', 'MUL1250-8', 'PMUL2847-2', 'SSNG0084-6', 'MUL1953-7', 'SNG0806-6', 'PMUL3349-6', 'SSNG0125-4', 'MUL2559-7', 'MUL2593-5', 'PMUL3827-4', 'SNG0872-4', 'MUL1714-8', 'PMUL0598-9', 'MUL0146-7', 'PMUL0049-6', 'SNG1305-1', 'PMUL1130-8', 'MUL0837-7', 'SNG1342-5', 'SNG02298-4', 'WOZ20170-4', 'PMUL2463-7', 'MUL1707-5', 'SNG1327-1', 'MUL0330-9', 'MUL2234-4', 'PMUL4330-7', 'MUL0108-6', 'SNG0706-4', 'SNG01384-2', 'PMUL4536-4', 'WOZ20364-3', 'PMUL1564-12', 'WOZ20288-3', 'SNG02090-2', 'MUL0940-5', 'PMUL4841-5', 'SNG0669-2', 'MUL2571-4', 'PMUL2369-7', 'WOZ20456-2', 'SNG01773-2', 'PMUL1190-3', 'SNG01519-2', 'PMUL0296-11', 'WOZ20401-4', 'MUL0054-5', 'PMUL4945-5', 'WOZ20402-4', 'MUL1118-9', 'MUL0581-5', 'PMUL3 ...
# Original Tokenizer Size is 32119
# ['<_PAD_>', '<go_r>', '<go_b>', '<go_a>', '<eos_u>', '<eos_r>', '<eos_b>', '<eos_a>', '<go_d>', '<eos_d>', '<sos_u>', '<sos_r>', '<sos_b>', '<sos_a>', '<sos_d>', '<sos_db>', '<eos_db>', '<sos_context>', '<eos_context>']
# Tokenizer Size after extension is 32119
# bos token is <pad>, eos token is </s>
# ['<sos_b>']
# ['<sos_a>']
# ['<sos_r>']
# 3
# ['<eos_b>']
# ['<eos_a>']
# ['<eos_r>']
# 3
# Tokenizing raw train data...
# self.train_data_id_list: 500
# Tokenizing raw dev data...
# Use only last turn of Validation set to validate...
# Tokenizing raw test data...
# The size of raw train, dev and test sets are 7901, 998 and 1000
# train turn number is 3507, dev turn number is 998, test turn number is 7372
# train_unlabelled_dialogue_id_list: 500 | ['ssng0348' 'pmul4047' 'pmul0151' 'pmul2203' 'mul0925' 'pmul0608'
#  'pmul2349' 'pmul2010' 'mul1052' 'sng02298' 'woz20358' 'mul1118'
#  'pmul1487' 'pmul0292' 'mul2559' 'pmul2187' 'sng1103' 'pmul2369'
#  'woz20645' 'pmul2290' 'pmul2752' 'woz20198' 'pmul4801' 'mul1239'
#  'sng0356' 'mul1949' 'mul0953' 'mul0611' 'sng0706' 'sng1326' 'pmul4494'
#  'pmul0200' 'pmul4951' 'pmul3005' 'mul1593' 'pmul1638' 'sng1305'
#  'woz20013' 'pmul4412' 'pmul4475' 'mul0552' 'woz20206' 'pmul3416'
#  'pmul1161' 'mul2109' 'pmul2278' 'pmul4477' 'pmul3863' 'mul0592'
#  'woz20000' 'mul0581' 'mul2029' 'woz20648' 'pmul1639' 'pmul4774' 'mul1792'
#  'sng1057' 'sng0300' 'pmul3767' 'sng0639' 'mul1990' 'mul0955' 'sng02106'
#  'pmul1390' 'mul2272' 'sng0562' 'ssng0299' 'mul0872' 'mul1707' 'pmul0842'
#  'mul1473' 'mul2178' 'sng01773' 'pmul3058' 'pmul3609' 'pmul2620'
#  'woz20638' 'pmul0370' 'mul2593' 'sng0818' 'mul2297' 'mul1878' 'mul1907'
#  'mul1404' 'ssng0048' 'pmul0305' 'mul2506' 'pmul2690' 'pmul3566'
#  'pmul0254' 'pmul2465' 'ssng0237' 'woz20057' 'mul2336' 'pmul3739'
#  'mul0194' 'pmul1287' 'sng1168' 'mul0766' 'sng02026' 'pmul1381' 'mul1129'
#  'woz20402' 'mul2363' 'pmul0261' 'woz20290' 'ssng0358' 'mul1300'
#  'sng02218' 'mul1802' 'mul1181' 'pmul1855' 'sng1151' 'pmul0939' 'sng1342'
#  'mul0390' 'sng01294' 'sng1395' 'woz20573' 'pmul4727' 'sng1264' 'pmul0824'
#  'pmul0880' 'sng0707' 'pmul1702' 'mul0856' 'pmul0101' 'pmul3009'
#  'pmul4991' 'woz20153' 'sng01771' 'sng0971' 'pmul0234' 'sng0265' 'mul1216'
#  'sng1299' 'mul2425' 'pmul0530' 'pmul3698' 'pmul4117' 'mul0295' 'mul0630'
#  'pmul3833' 'mul1717' 'pmul0326' 'pmul3857' 'sng1217' 'sng0878' 'pmul0324'
#  'mul1250' 'pmul4690' 'pmul1130' 'pmul1044' 'ssng0274' 'ssng0229'
#  'ssng0058' 'mul0521' 'mul2509' 'mul1170' 'pmul2461' 'pmul3281' 'sng0036'
#  'sng0499' 'woz20667' 'mul2094' 'mul1397' 'ssng0009' 'pmul1010' 'woz20319'
#  'mul0156' 'pmul2976' 'woz20377' 'sng0488' 'pmul1767' 'mul1591' 'pmul2537'
#  'pmul1646' 'pmul1924' 'sng1332' 'pmul2110' 'mul0015' 'pmul0395' 'sng0504'
#  'pmul2808' 'ssng0262' 'ssng0125' 'pmul3967' 'pmul0478' 'woz20313'
#  'mul0497' 'pmul0964' 'ssng0005' 'pmul1989' 'mul0184' 'mul1785' 'pmul0542'
#  'pmul4822' 'mul1864' 'pmul3259' 'sng01717' 'pmul1913' 'mul0758' 'sng1356'
#  'pmul4330' 'pmul1576' 'mul1714' 'pmul0297' 'sng0802' 'pmul0971'
#  'pmul1873' 'mul1068' 'mul0940' 'ssng0197' 'woz20533' 'woz20189' 'mul2558'
#  'sng0025' 'pmul3454' 'pmul4917' 'mul2561' 'mul1086' 'pmul4961' 'ssng0171'
#  'pmul1634' 'pmul3154' 'sng0683' 'pmul4081' 'woz20278' 'mul0254'
#  'pmul2583' 'mul1155' 'pmul2523' 'mul0550' 'pmul4342' 'mul0327' 'mul0928'
#  'sng0806' 'mul2145' 'pmul1567' 'ssng0185' 'pmul0885' 'pmul2741'
#  'pmul3155' 'ssng0084' 'pmul0775' 'mul2404' 'mul1498' 'sng0765' 'mul2095'
#  'pmul4182' 'pmul1053' 'ssng0035' 'pmul2137' 'pmul0354' 'woz20496'
#  'sng1140' 'sng0315' 'pmul0373' 'mul2371' 'pmul0150' 'mul0066' 'pmul3385'
#  'pmul2987' 'pmul0808' 'mul2234' 'pmul3538' 'pmul4508' 'pmul0383'
#  'woz20587' 'sng1327' 'mul1196' 'pmul1691' 'pmul3771' 'pmul0800' 'mul0969'
#  'mul1229' 'pmul1349' 'mul0101' 'woz20194' 'pmul4954' 'mul1563' 'woz20169'
#  'sng1242' 'woz20170' 'ssng0372' 'mul0876' 'pmul0981' 'pmul1738'
#  'pmul4563' 'mul2663' 'pmul3125' 'woz20364' 'mul2308' 'ssng0374'
#  'pmul4745' 'mul2176' 'mul0919' 'pmul2524' 'ssng0082' 'sng1281' 'pmul0316'
#  'sng01545' 'pmul0459' 'sng01519' 'pmul1668' 'pmul4114' 'pmul2672'
#  'sng02084' 'pmul3371' 'pmul3831' 'mul0122' 'pmul2978' 'pmul1850'
#  'mul0195' 'pmul3033' 'mul1499' 'pmul0722' 'mul0560' 'pmul1404' 'pmul4945'
#  'pmul2501' 'pmul4135' 'mul1401' 'pmul3513' 'mul0449' 'mul2571' 'mul2611'
#  'pmul4841' 'mul0028' 'pmul2357' 'ssng0389' 'pmul2884' 'mul0330'
#  'pmul2870' 'pmul0952' 'pmul1489' 'woz20046' 'pmul0126' 'sng0869'
#  'pmul2709' 'pmul3349' 'pmul0131' 'pmul3616' 'pmul2342' 'pmul3963'
#  'pmul4243' 'pmul3757' 'pmul0897' 'pmul0218' 'pmul1475' 'mul0824'
#  'mul1079' 'mul1524' 'mul1308' 'mul0406' 'mul0263' 'sng1104' 'pmul0580'
#  'woz20018' 'pmul1190' 'mul0146' 'pmul0309' 'pmul2967' 'mul1236' 'mul2033'
#  'pmul0049' 'mul0837' 'pmul4653' 'woz20177' 'pmul4887' 'woz20288'
#  'pmul1758' 'mul2136' 'mul0210' 'pmul2439' 'pmul1643' 'sng0761' 'pmul2814'
#  'mul0399' 'pmul0437' 'woz20246' 'ssng0175' 'pmul2281' 'pmul3476'
#  'pmul2158' 'pmul4238' 'mul0137' 'pmul2356' 'pmul1564' 'pmul0384'
#  'pmul1024' 'pmul2451' 'sng02090' 'ssng0169' 'sng01622' 'pmul4193'
#  'sng0453' 'sng0669' 'pmul0466' 'mul0020' 'ssng0317' 'mul1038' 'woz20519'
#  'mul1439' 'mul2691' 'mul1063' 'mul0192' 'sng1145' 'pmul3343' 'mul0451'
#  'sng0653' 'pmul0598' 'pmul3881' 'pmul2684' 'pmul4096' 'sng01674'
#  'mul0108' 'mul2182' 'sng1250' 'pmul4105' 'pmul3671' 'sng0262' 'pmul3827'
#  'pmul4997' 'sng02248' 'mul1688' 'mul1353' 'sng0876' 'mul1962' 'mul0802'
#  'pmul2760' 'sng1317' 'sng01697' 'pmul3102' 'ssng0144' 'sng0731' 'mul1333'
#  'woz20456' 'pmul0103' 'mul2472' 'sng0596' 'sng0559' 'pmul4585' 'sng02150'
#  'sng0872' 'mul2050' 'ssng0081' 'mul0284' 'mul0502' 'woz20401' 'pmul2964'
#  'pmul0502' 'mul2521' 'pmul1315' 'pmul1746' 'mul0930' 'pmul2631' 'sng0540'
#  'mul0054' 'mul1471' 'sng01339' 'pmul0050' 'mul2485' 'mul1054' 'pmul2600'
#  'mul2202' 'mul0500' 'pmul2554' 'pmul4528' 'sng02103' 'mul0087' 'pmul2463'
#  'pmul3945' 'pmul0834' 'pmul0296' 'pmul3316' 'pmul2847' 'sng01712'
#  'pmul1527' 'pmul4536' 'pmul1544' 'mul0226' 'pmul2099' 'pmul1204'
#  'sng0574' 'mul2636' 'sng0976' 'ssng0397' 'mul0318' 'pmul2291' 'pmul1703'
#  'pmul0411' 'pmul3877' 'woz20410' 'mul1953' 'sng01384' 'sng01862'
#  'mul0277' 'pmul2387' 'pmul4251']
# num_dialogue_per_round: 100
# total_round: 5
# ============= Initializing model =============
# Start loading model...
# loading model from pretrained...
# Initializing Huggingface T5 model...
# Resizing Token Embeddings...
# Model loaded
# =================== Run Active Learning ===================
# ============= round index: [0/5] =============
# selected_ids: 100 ['pmul2369' 'pmul3009' 'mul1236' 'mul1907' 'mul1990' 'ssng0035' 'mul2371'
#  'pmul2709' 'pmul0971' 'mul0872' 'mul1439' 'pmul0466' 'pmul2808'
#  'ssng0009' 'pmul0842' 'sng0262' 'pmul3513' 'pmul4536' 'mul2363'
#  'sng01712' 'pmul3833' 'mul1792' 'pmul1564' 'pmul2631' 'sng01384'
#  'pmul0126' 'sng0504' 'pmul2187' 'mul0630' 'pmul4508' 'pmul0383' 'sng1151'
#  'sng02106' 'sng01622' 'mul0766' 'ssng0185' 'pmul2967' 'ssng0169'
#  'mul0930' 'pmul0411' 'pmul3616' 'pmul2451' 'mul1063' 'mul0406' 'mul2178'
#  'pmul3155' 'pmul1643' 'pmul2847' 'pmul2976' 'pmul3963' 'mul1717'
#  'pmul1287' 'pmul4412' 'pmul2752' 'ssng0317' 'pmul0834' 'pmul1204'
#  'mul0856' 'pmul0296' 'sng02090' 'mul0611' 'mul0502' 'ssng0372' 'pmul3385'
#  'mul1688' 'pmul0050' 'pmul3033' 'sng01771' 'pmul4342' 'sng1264'
#  'pmul4081' 'mul0137' 'mul0254' 'woz20402' 'sng1332' 'mul2404' 'mul0928'
#  'pmul1850' 'pmul0981' 'pmul3102' 'pmul2439' 'pmul4182' 'woz20519'
#  'mul2663' 'pmul2099' 'pmul4563' 'sng1395' 'pmul2461' 'mul0940' 'pmul1475'
#  'pmul4690' 'pmul1638' 'ssng0125' 'mul0284' 'mul0087' 'mul2272' 'sng01339'
#  'sng0639' 'pmul2291' 'mul0015']
# unselected_ids: 400 ['mul0020' 'mul0028' 'mul0054' 'mul0066' 'mul0101' 'mul0108' 'mul0122'
#  'mul0146' 'mul0156' 'mul0184' 'mul0192' 'mul0194' 'mul0195' 'mul0210'
#  'mul0226' 'mul0263' 'mul0277' 'mul0295' 'mul0318' 'mul0327' 'mul0330'
#  'mul0390' 'mul0399' 'mul0449' 'mul0451' 'mul0497' 'mul0500' 'mul0521'
#  'mul0550' 'mul0552' 'mul0560' 'mul0581' 'mul0592' 'mul0758' 'mul0802'
#  'mul0824' 'mul0837' 'mul0876' 'mul0919' 'mul0925' 'mul0953' 'mul0955'
#  'mul0969' 'mul1038' 'mul1052' 'mul1054' 'mul1068' 'mul1079' 'mul1086'
#  'mul1118' 'mul1129' 'mul1155' 'mul1170' 'mul1181' 'mul1196' 'mul1216'
#  'mul1229' 'mul1239' 'mul1250' 'mul1300' 'mul1308' 'mul1333' 'mul1353'
#  'mul1397' 'mul1401' 'mul1404' 'mul1471' 'mul1473' 'mul1498' 'mul1499'
#  'mul1524' 'mul1563' 'mul1591' 'mul1593' 'mul1707' 'mul1714' 'mul1785'
#  'mul1802' 'mul1864' 'mul1878' 'mul1949' 'mul1953' 'mul1962' 'mul2029'
#  'mul2033' 'mul2050' 'mul2094' 'mul2095' 'mul2109' 'mul2136' 'mul2145'
#  'mul2176' 'mul2182' 'mul2202' 'mul2234' 'mul2297' 'mul2308' 'mul2336'
#  'mul2425' 'mul2472' 'mul2485' 'mul2506' 'mul2509' 'mul2521' 'mul2558'
#  'mul2559' 'mul2561' 'mul2571' 'mul2593' 'mul2611' 'mul2636' 'mul2691'
#  'pmul0049' 'pmul0101' 'pmul0103' 'pmul0131' 'pmul0150' 'pmul0151'
#  'pmul0200' 'pmul0218' 'pmul0234' 'pmul0254' 'pmul0261' 'pmul0292'
#  'pmul0297' 'pmul0305' 'pmul0309' 'pmul0316' 'pmul0324' 'pmul0326'
#  'pmul0354' 'pmul0370' 'pmul0373' 'pmul0384' 'pmul0395' 'pmul0437'
#  'pmul0459' 'pmul0478' 'pmul0502' 'pmul0530' 'pmul0542' 'pmul0580'
#  'pmul0598' 'pmul0608' 'pmul0722' 'pmul0775' 'pmul0800' 'pmul0808'
#  'pmul0824' 'pmul0880' 'pmul0885' 'pmul0897' 'pmul0939' 'pmul0952'
#  'pmul0964' 'pmul1010' 'pmul1024' 'pmul1044' 'pmul1053' 'pmul1130'
#  'pmul1161' 'pmul1190' 'pmul1315' 'pmul1349' 'pmul1381' 'pmul1390'
#  'pmul1404' 'pmul1487' 'pmul1489' 'pmul1527' 'pmul1544' 'pmul1567'
#  'pmul1576' 'pmul1634' 'pmul1639' 'pmul1646' 'pmul1668' 'pmul1691'
#  'pmul1702' 'pmul1703' 'pmul1738' 'pmul1746' 'pmul1758' 'pmul1767'
#  'pmul1855' 'pmul1873' 'pmul1913' 'pmul1924' 'pmul1989' 'pmul2010'
#  'pmul2110' 'pmul2137' 'pmul2158' 'pmul2203' 'pmul2278' 'pmul2281'
#  'pmul2290' 'pmul2342' 'pmul2349' 'pmul2356' 'pmul2357' 'pmul2387'
#  'pmul2463' 'pmul2465' 'pmul2501' 'pmul2523' 'pmul2524' 'pmul2537'
#  'pmul2554' 'pmul2583' 'pmul2600' 'pmul2620' 'pmul2672' 'pmul2684'
#  'pmul2690' 'pmul2741' 'pmul2760' 'pmul2814' 'pmul2870' 'pmul2884'
#  'pmul2964' 'pmul2978' 'pmul2987' 'pmul3005' 'pmul3058' 'pmul3125'
#  'pmul3154' 'pmul3259' 'pmul3281' 'pmul3316' 'pmul3343' 'pmul3349'
#  'pmul3371' 'pmul3416' 'pmul3454' 'pmul3476' 'pmul3538' 'pmul3566'
#  'pmul3609' 'pmul3671' 'pmul3698' 'pmul3739' 'pmul3757' 'pmul3767'
#  'pmul3771' 'pmul3827' 'pmul3831' 'pmul3857' 'pmul3863' 'pmul3877'
#  'pmul3881' 'pmul3945' 'pmul3967' 'pmul4047' 'pmul4096' 'pmul4105'
#  'pmul4114' 'pmul4117' 'pmul4135' 'pmul4193' 'pmul4238' 'pmul4243'
#  'pmul4251' 'pmul4330' 'pmul4475' 'pmul4477' 'pmul4494' 'pmul4528'
#  'pmul4585' 'pmul4653' 'pmul4727' 'pmul4745' 'pmul4774' 'pmul4801'
#  'pmul4822' 'pmul4841' 'pmul4887' 'pmul4917' 'pmul4945' 'pmul4951'
#  'pmul4954' 'pmul4961' 'pmul4991' 'pmul4997' 'sng0025' 'sng0036'
#  'sng01294' 'sng01519' 'sng01545' 'sng01674' 'sng01697' 'sng01717'
#  'sng01773' 'sng01862' 'sng02026' 'sng02084' 'sng02103' 'sng02150'
#  'sng02218' 'sng02248' 'sng02298' 'sng0265' 'sng0300' 'sng0315' 'sng0356'
#  'sng0453' 'sng0488' 'sng0499' 'sng0540' 'sng0559' 'sng0562' 'sng0574'
#  'sng0596' 'sng0653' 'sng0669' 'sng0683' 'sng0706' 'sng0707' 'sng0731'
#  'sng0761' 'sng0765' 'sng0802' 'sng0806' 'sng0818' 'sng0869' 'sng0872'
#  'sng0876' 'sng0878' 'sng0971' 'sng0976' 'sng1057' 'sng1103' 'sng1104'
#  'sng1140' 'sng1145' 'sng1168' 'sng1217' 'sng1242' 'sng1250' 'sng1281'
#  'sng1299' 'sng1305' 'sng1317' 'sng1326' 'sng1327' 'sng1342' 'sng1356'
#  'ssng0005' 'ssng0048' 'ssng0058' 'ssng0081' 'ssng0082' 'ssng0084'
#  'ssng0144' 'ssng0171' 'ssng0175' 'ssng0197' 'ssng0229' 'ssng0237'
#  'ssng0262' 'ssng0274' 'ssng0299' 'ssng0348' 'ssng0358' 'ssng0374'
#  'ssng0389' 'ssng0397' 'woz20000' 'woz20013' 'woz20018' 'woz20046'
#  'woz20057' 'woz20153' 'woz20169' 'woz20170' 'woz20177' 'woz20189'
#  'woz20194' 'woz20198' 'woz20206' 'woz20246' 'woz20278' 'woz20288'
#  'woz20290' 'woz20313' 'woz20319' 'woz20358' 'woz20364' 'woz20377'
#  'woz20401' 'woz20410' 'woz20456' 'woz20496' 'woz20533' 'woz20573'
#  'woz20587' 'woz20638' 'woz20645' 'woz20648' 'woz20667']
# +++++++++++++++ dialogue per round: [0/99] total round: [0/5] current selected_dialogue_id: pmul2369 +++++++++++++++
# dialogue_turns: 8
# use Least Confidence to select turn
# confidence_list: [304.2835693359375, 217.65420532226562, 208.69290161132812, 260.9715270996094, 261.530517578125, 224.99075317382812, 229.27023315429688, 228.84881591796875]
# selected_turn_id: 2
# min_confidence: 208.69290161132812
# selected turn: PMUL2369-2 max_entropy: 0 min_confidence: 208.69290161132812
# +++++++++++++++ dialogue per round: [1/99] total round: [0/5] current selected_dialogue_id: pmul3009 +++++++++++++++
# dialogue_turns: 10
# use Least Confidence to select turn
# confidence_list: [597.88232421875, 653.2815551757812, 586.7830810546875, 637.16357421875, 683.8046875, 620.1201171875, 595.8159790039062, 403.9746398925781, 404.679443359375, 406.9795837402344]
# selected_turn_id: 7
# min_confidence: 403.9746398925781
# selected turn: PMUL3009-7 max_entropy: 0 min_confidence: 403.9746398925781
# +++++++++++++++ dialogue per round: [2/99] total round: [0/5] current selected_dialogue_id: mul1236 +++++++++++++++
# dialogue_turns: 11
# use Least Confidence to select turn
# confidence_list: [1600.16943359375, 1547.4093017578125, 1545.8759765625, 1554.5867919921875, 1320.95703125, 1232.06982421875, 1232.671630859375, 1253.1114501953125, 914.8982543945312, 964.9161376953125, 963.0043334960938]
# selected_turn_id: 8
# min_confidence: 914.8982543945312
# selected turn: MUL1236-8 max_entropy: 0 min_confidence: 914.8982543945312
# +++++++++++++++ dialogue per round: [3/99] total round: [0/5] current selected_dialogue_id: mul1907 +++++++++++++++
# dialogue_turns: 6
# use Least Confidence to select turn
# confidence_list: [523.4573364257812, 494.4639587402344, 390.8162841796875, 242.93276977539062, 234.17431640625, 231.5582275390625]
# selected_turn_id: 5
# min_confidence: 231.5582275390625
# selected turn: MUL1907-5 max_entropy: 0 min_confidence: 231.5582275390625
# +++++++++++++++ dialogue per round: [4/99] total round: [0/5] current selected_dialogue_id: mul1990 +++++++++++++++
# dialogue_turns: 8
# use Least Confidence to select turn
# confidence_list: [878.4152221679688, 835.802001953125, 882.76416015625, 532.7490234375, 370.20196533203125, 377.17578125, 375.5826416015625, 370.454345703125]
# selected_turn_id: 4
# min_confidence: 370.20196533203125
# selected turn: MUL1990-4 max_entropy: 0 min_confidence: 370.20196533203125
# +++++++++++++++ dialogue per round: [5/99] total round: [0/5] current selected_dialogue_id: ssng0035 +++++++++++++++
# dialogue_turns: 7
# use Least Confidence to select turn
# confidence_list: [534.2318725585938, 402.1849365234375, 357.59783935546875, 357.8810119628906, 450.1399230957031, 450.0910949707031, 447.0776672363281]
# selected_turn_id: 2
# min_confidence: 357.59783935546875
# selected turn: SSNG0035-2 max_entropy: 0 min_confidence: 357.59783935546875
# +++++++++++++++ dialogue per round: [6/99] total round: [0/5] current selected_dialogue_id: mul2371 +++++++++++++++
# dialogue_turns: 5
# use Least Confidence to select turn
# confidence_list: [649.7749633789062, 449.9207763671875, 377.498291015625, 516.2703247070312, 452.37969970703125]
# selected_turn_id: 2
# min_confidence: 377.498291015625
# selected turn: MUL2371-2 max_entropy: 0 min_confidence: 377.498291015625
# +++++++++++++++ dialogue per round: [7/99] total round: [0/5] current selected_dialogue_id: pmul2709 +++++++++++++++
# dialogue_turns: 8
# use Least Confidence to select turn
# confidence_list: [384.13922119140625, 237.5991668701172, 269.9722900390625, 283.2913818359375, 405.63726806640625, 414.10833740234375, 403.0095520019531, 404.30426025390625]
# selected_turn_id: 1
# min_confidence: 237.5991668701172
# selected turn: PMUL2709-1 max_entropy: 0 min_confidence: 237.5991668701172
# +++++++++++++++ dialogue per round: [8/99] total round: [0/5] current selected_dialogue_id: pmul0971 +++++++++++++++
# dialogue_turns: 3
# use Least Confidence to select turn
# confidence_list: [291.49658203125, 240.4329833984375, 243.95782470703125]
# selected_turn_id: 1
# min_confidence: 240.4329833984375
# selected turn: PMUL0971-1 max_entropy: 0 min_confidence: 240.4329833984375
# +++++++++++++++ dialogue per round: [9/99] total round: [0/5] current selected_dialogue_id: mul0872 +++++++++++++++
# dialogue_turns: 8
# use Least Confidence to select turn
# confidence_list: [874.0623779296875, 829.6226806640625, 760.1101684570312, 868.8720703125, 866.7703857421875, 546.0067138671875, 879.2540283203125, 537.0923461914062]
# selected_turn_id: 7
# min_confidence: 537.0923461914062
# selected turn: MUL0872-7 max_entropy: 0 min_confidence: 537.0923461914062
# +++++++++++++++ dialogue per round: [10/99] total round: [0/5] current selected_dialogue_id: mul1439 +++++++++++++++
# dialogue_turns: 7
# use Least Confidence to select turn
# confidence_list: [260.6742248535156, 257.00311279296875, 214.65257263183594, 213.68617248535156, 214.7917938232422, 219.48892211914062, 219.99085998535156]
# selected_turn_id: 3
# min_confidence: 213.68617248535156
# selected turn: MUL1439-3 max_entropy: 0 min_confidence: 213.68617248535156
# +++++++++++++++ dialogue per round: [11/99] total round: [0/5] current selected_dialogue_id: pmul0466 +++++++++++++++
# dialogue_turns: 10
# use Least Confidence to select turn
# confidence_list: [894.1181640625, 858.187255859375, 896.8158569335938, 903.3732299804688, 768.074462890625, 540.009521484375, 793.9139404296875, 803.6591796875, 718.89404296875, 725.963134765625]
# selected_turn_id: 5
# min_confidence: 540.009521484375
# selected turn: PMUL0466-5 max_entropy: 0 min_confidence: 540.009521484375
# +++++++++++++++ dialogue per round: [12/99] total round: [0/5] current selected_dialogue_id: pmul2808 +++++++++++++++
# dialogue_turns: 11
# use Least Confidence to select turn
# confidence_list: [2012.204833984375, 1794.4556884765625, 1755.5396728515625, 1688.6920166015625, 1699.0030517578125, 1428.3841552734375, 1372.7254638671875, 1266.787841796875, 1135.4521484375, 814.8602905273438, 949.1273193359375]
# selected_turn_id: 9
# min_confidence: 814.8602905273438
# selected turn: PMUL2808-9 max_entropy: 0 min_confidence: 814.8602905273438
# +++++++++++++++ dialogue per round: [13/99] total round: [0/5] current selected_dialogue_id: ssng0009 +++++++++++++++
# dialogue_turns: 5
# use Least Confidence to select turn
# confidence_list: [597.2322998046875, 496.0400085449219, 374.4684753417969, 376.19635009765625, 372.29150390625]
# selected_turn_id: 4
# min_confidence: 372.29150390625
# selected turn: SSNG0009-4 max_entropy: 0 min_confidence: 372.29150390625
# +++++++++++++++ dialogue per round: [14/99] total round: [0/5] current selected_dialogue_id: pmul0842 +++++++++++++++
# dialogue_turns: 9
# use Least Confidence to select turn
# confidence_list: [1504.3194580078125, 1477.966796875, 1447.74658203125, 1304.470703125, 720.2775268554688, 716.9326782226562, 621.1968383789062, 620.5888061523438, 618.9483642578125]
# selected_turn_id: 8
# min_confidence: 618.9483642578125
# selected turn: PMUL0842-8 max_entropy: 0 min_confidence: 618.9483642578125
# +++++++++++++++ dialogue per round: [15/99] total round: [0/5] current selected_dialogue_id: sng0262 +++++++++++++++
# dialogue_turns: 5
# use Least Confidence to select turn
# confidence_list: [910.7793579101562, 768.9631958007812, 355.58892822265625, 293.54656982421875, 282.90521240234375]
# selected_turn_id: 4
# min_confidence: 282.90521240234375
# selected turn: SNG0262-4 max_entropy: 0 min_confidence: 282.90521240234375
# +++++++++++++++ dialogue per round: [16/99] total round: [0/5] current selected_dialogue_id: pmul3513 +++++++++++++++
# dialogue_turns: 14
# use Least Confidence to select turn
# confidence_list: [1339.791015625, 1321.4605712890625, 1274.6497802734375, 811.989990234375, 721.5529174804688, 726.2833251953125, 725.2015380859375, 701.0426635742188, 1290.5078125, 982.3456420898438, 988.1353759765625, 774.6808471679688, 1073.4261474609375, 694.86474609375]
# selected_turn_id: 13
# min_confidence: 694.86474609375
# selected turn: PMUL3513-13 max_entropy: 0 min_confidence: 694.86474609375
# +++++++++++++++ dialogue per round: [17/99] total round: [0/5] current selected_dialogue_id: pmul4536 +++++++++++++++
# dialogue_turns: 5
# use Least Confidence to select turn
# confidence_list: [1501.066650390625, 1497.546630859375, 1002.5704345703125, 883.5120849609375, 502.3589782714844]
# selected_turn_id: 4
# min_confidence: 502.3589782714844
# selected turn: PMUL4536-4 max_entropy: 0 min_confidence: 502.3589782714844
# +++++++++++++++ dialogue per round: [18/99] total round: [0/5] current selected_dialogue_id: mul2363 +++++++++++++++
# dialogue_turns: 8
# use Least Confidence to select turn
# confidence_list: [859.8046264648438, 840.421630859375, 873.9305419921875, 863.8692626953125, 854.7503051757812, 870.2213745117188, 568.8352661132812, 496.0267333984375]
# selected_turn_id: 7
# min_confidence: 496.0267333984375
# selected turn: MUL2363-7 max_entropy: 0 min_confidence: 496.0267333984375
# +++++++++++++++ dialogue per round: [19/99] total round: [0/5] current selected_dialogue_id: sng01712 +++++++++++++++
# dialogue_turns: 4
# use Least Confidence to select turn
# confidence_list: [343.344482421875, 271.5613098144531, 240.264404296875, 234.7969207763672]
# selected_turn_id: 3
# min_confidence: 234.7969207763672
# selected turn: SNG01712-3 max_entropy: 0 min_confidence: 234.7969207763672
# +++++++++++++++ dialogue per round: [20/99] total round: [0/5] current selected_dialogue_id: pmul3833 +++++++++++++++
# dialogue_turns: 6
# use Least Confidence to select turn
# confidence_list: [729.7589111328125, 557.008056640625, 433.5230407714844, 324.2587890625, 309.8492126464844, 312.4247131347656]
# selected_turn_id: 4
# min_confidence: 309.8492126464844
# selected turn: PMUL3833-4 max_entropy: 0 min_confidence: 309.8492126464844
# +++++++++++++++ dialogue per round: [21/99] total round: [0/5] current selected_dialogue_id: mul1792 +++++++++++++++
# dialogue_turns: 6
# use Least Confidence to select turn
# confidence_list: [610.4317626953125, 431.2397155761719, 433.92108154296875, 350.84124755859375, 348.0963134765625, 347.56890869140625]
# selected_turn_id: 5
# min_confidence: 347.56890869140625
# selected turn: MUL1792-5 max_entropy: 0 min_confidence: 347.56890869140625
# +++++++++++++++ dialogue per round: [22/99] total round: [0/5] current selected_dialogue_id: pmul1564 +++++++++++++++
# dialogue_turns: 13
# use Least Confidence to select turn
# confidence_list: [1233.9122314453125, 871.3036499023438, 652.85302734375, 652.2211303710938, 632.5335083007812, 634.8778686523438, 625.3627319335938, 479.1107482910156, 395.5252990722656, 403.71697998046875, 406.1773376464844, 406.4093322753906, 406.76025390625]
# selected_turn_id: 8
# min_confidence: 395.5252990722656
# selected turn: PMUL1564-8 max_entropy: 0 min_confidence: 395.5252990722656
# +++++++++++++++ dialogue per round: [23/99] total round: [0/5] current selected_dialogue_id: pmul2631 +++++++++++++++
# dialogue_turns: 6
# use Least Confidence to select turn
# confidence_list: [866.4567260742188, 455.925537109375, 465.8258361816406, 422.0021667480469, 377.98651123046875, 381.7072448730469]
# selected_turn_id: 4
# min_confidence: 377.98651123046875
# selected turn: PMUL2631-4 max_entropy: 0 min_confidence: 377.98651123046875
# +++++++++++++++ dialogue per round: [24/99] total round: [0/5] current selected_dialogue_id: sng01384 +++++++++++++++
# dialogue_turns: 3
# use Least Confidence to select turn
# confidence_list: [372.44091796875, 343.572509765625, 339.5765075683594]
# selected_turn_id: 2
# min_confidence: 339.5765075683594
# selected turn: SNG01384-2 max_entropy: 0 min_confidence: 339.5765075683594
# +++++++++++++++ dialogue per round: [25/99] total round: [0/5] current selected_dialogue_id: pmul0126 +++++++++++++++
# dialogue_turns: 9
# use Least Confidence to select turn
# confidence_list: [664.4351806640625, 598.7532348632812, 637.5217895507812, 636.073974609375, 628.6142578125, 614.5220336914062, 620.81640625, 419.9802551269531, 427.15618896484375]
# selected_turn_id: 7
# min_confidence: 419.9802551269531
# selected turn: PMUL0126-7 max_entropy: 0 min_confidence: 419.9802551269531
# +++++++++++++++ dialogue per round: [26/99] total round: [0/5] current selected_dialogue_id: sng0504 +++++++++++++++
# dialogue_turns: 4
# use Least Confidence to select turn
# confidence_list: [451.60125732421875, 464.4521484375, 302.3917236328125, 291.0089416503906]
# selected_turn_id: 3
# min_confidence: 291.0089416503906
# selected turn: SNG0504-3 max_entropy: 0 min_confidence: 291.0089416503906
# +++++++++++++++ dialogue per round: [27/99] total round: [0/5] current selected_dialogue_id: pmul2187 +++++++++++++++
# dialogue_turns: 11
# use Least Confidence to select turn
# confidence_list: [760.5042724609375, 691.9844970703125, 735.6365966796875, 790.3524780273438, 754.3953247070312, 753.21337890625, 765.620849609375, 593.6737060546875, 432.15216064453125, 429.9649658203125, 434.53594970703125]
# selected_turn_id: 9
# min_confidence: 429.9649658203125
# selected turn: PMUL2187-9 max_entropy: 0 min_confidence: 429.9649658203125
# +++++++++++++++ dialogue per round: [28/99] total round: [0/5] current selected_dialogue_id: mul0630 +++++++++++++++
# dialogue_turns: 9
# use Least Confidence to select turn
# confidence_list: [1353.60009765625, 1305.0565185546875, 1181.9417724609375, 1089.3936767578125, 561.0302734375, 538.4332885742188, 469.7581787109375, 464.6223449707031, 478.80224609375]
# selected_turn_id: 7
# ...
# selected_turn_id: 4
# min_confidence: 520.864990234375
# selected turn: MUL0928-4 max_entropy: 0 min_confidence: 520.864990234375
# +++++++++++++++ dialogue per round: [77/99] total round: [0/5] current selected_dialogue_id: pmul1850 +++++++++++++++
# dialogue_turns: 6
# use Least Confidence to select turn
# confidence_list: [1188.226806640625, 722.85888671875, 638.5718383789062, 413.4161682128906, 417.3264465332031, 421.0892333984375]
# selected_turn_id: 3
# min_confidence: 413.4161682128906
# selected turn: PMUL1850-3 max_entropy: 0 min_confidence: 413.4161682128906
# +++++++++++++++ dialogue per round: [78/99] total round: [0/5] current selected_dialogue_id: pmul0981 +++++++++++++++
# dialogue_turns: 7
# use Least Confidence to select turn
# confidence_list: [992.1834716796875, 851.1521606445312, 813.5264282226562, 560.48291015625, 488.37774658203125, 496.3777160644531, 503.08392333984375]
# selected_turn_id: 4
# min_confidence: 488.37774658203125
# selected turn: PMUL0981-4 max_entropy: 0 min_confidence: 488.37774658203125
# +++++++++++++++ dialogue per round: [79/99] total round: [0/5] current selected_dialogue_id: pmul3102 +++++++++++++++
# dialogue_turns: 8
# use Least Confidence to select turn
# confidence_list: [1794.2734375, 1781.611328125, 1577.3192138671875, 1620.14697265625, 957.8865966796875, 646.3967895507812, 624.3871459960938, 754.4219970703125]
# selected_turn_id: 6
# min_confidence: 624.3871459960938
# selected turn: PMUL3102-6 max_entropy: 0 min_confidence: 624.3871459960938
# +++++++++++++++ dialogue per round: [80/99] total round: [0/5] current selected_dialogue_id: pmul2439 +++++++++++++++
# dialogue_turns: 6
# use Least Confidence to select turn
# confidence_list: [659.7390747070312, 521.6806640625, 494.8434753417969, 347.0888977050781, 341.72772216796875, 500.8383483886719]
# selected_turn_id: 4
# min_confidence: 341.72772216796875
# selected turn: PMUL2439-4 max_entropy: 0 min_confidence: 341.72772216796875
# +++++++++++++++ dialogue per round: [81/99] total round: [0/5] current selected_dialogue_id: pmul4182 +++++++++++++++
# dialogue_turns: 7
# use Least Confidence to select turn
# confidence_list: [1348.6116943359375, 1181.7801513671875, 967.7507934570312, 1166.45166015625, 758.2193603515625, 662.42333984375, 655.5064697265625]
# selected_turn_id: 6
# min_confidence: 655.5064697265625
# selected turn: PMUL4182-6 max_entropy: 0 min_confidence: 655.5064697265625
# +++++++++++++++ dialogue per round: [82/99] total round: [0/5] current selected_dialogue_id: woz20519 +++++++++++++++
# dialogue_turns: 3
# use Least Confidence to select turn
# confidence_list: [182.92454528808594, 182.51309204101562, 184.74293518066406]
# selected_turn_id: 1
# min_confidence: 182.51309204101562
# selected turn: WOZ20519-1 max_entropy: 0 min_confidence: 182.51309204101562
# +++++++++++++++ dialogue per round: [83/99] total round: [0/5] current selected_dialogue_id: mul2663 +++++++++++++++
# dialogue_turns: 5
# use Least Confidence to select turn
# confidence_list: [269.343505859375, 239.04281616210938, 290.5726013183594, 288.1358642578125, 287.95465087890625]
# selected_turn_id: 1
# min_confidence: 239.04281616210938
# selected turn: MUL2663-1 max_entropy: 0 min_confidence: 239.04281616210938
# +++++++++++++++ dialogue per round: [84/99] total round: [0/5] current selected_dialogue_id: pmul2099 +++++++++++++++
# dialogue_turns: 7
# use Least Confidence to select turn
# confidence_list: [664.3372802734375, 651.4118041992188, 323.4827575683594, 519.3594970703125, 531.934814453125, 525.5767822265625, 520.9614868164062]
# selected_turn_id: 2
# min_confidence: 323.4827575683594
# selected turn: PMUL2099-2 max_entropy: 0 min_confidence: 323.4827575683594
# +++++++++++++++ dialogue per round: [85/99] total round: [0/5] current selected_dialogue_id: pmul4563 +++++++++++++++
# dialogue_turns: 13
# use Least Confidence to select turn
# confidence_list: [1438.3782958984375, 1446.6766357421875, 1461.9432373046875, 1380.2347412109375, 1070.6129150390625, 836.37158203125, 836.5848388671875, 979.9603271484375, 840.6526489257812, 666.9276123046875, 704.09375, 688.60009765625, 686.754150390625]
# selected_turn_id: 9
# min_confidence: 666.9276123046875
# selected turn: PMUL4563-9 max_entropy: 0 min_confidence: 666.9276123046875
# +++++++++++++++ dialogue per round: [86/99] total round: [0/5] current selected_dialogue_id: sng1395 +++++++++++++++
# dialogue_turns: 4
# use Least Confidence to select turn
# confidence_list: [529.0101318359375, 350.20074462890625, 259.6313781738281, 249.68045043945312]
# selected_turn_id: 3
# min_confidence: 249.68045043945312
# selected turn: SNG1395-3 max_entropy: 0 min_confidence: 249.68045043945312
# +++++++++++++++ dialogue per round: [87/99] total round: [0/5] current selected_dialogue_id: pmul2461 +++++++++++++++
# dialogue_turns: 13
# use Least Confidence to select turn
# confidence_list: [571.3148803710938, 620.2704467773438, 553.4526977539062, 523.0022583007812, 412.11407470703125, 545.5593872070312, 352.5888671875, 332.0027160644531, 333.8721923828125, 365.2348937988281, 327.5545349121094, 326.619873046875, 327.70904541015625]
# selected_turn_id: 11
# min_confidence: 326.619873046875
# selected turn: PMUL2461-11 max_entropy: 0 min_confidence: 326.619873046875
# +++++++++++++++ dialogue per round: [88/99] total round: [0/5] current selected_dialogue_id: mul0940 +++++++++++++++
# dialogue_turns: 6
# use Least Confidence to select turn
# confidence_list: [798.5780639648438, 830.8755493164062, 869.442626953125, 647.3494262695312, 506.5697326660156, 511.3345947265625]
# selected_turn_id: 4
# min_confidence: 506.5697326660156
# selected turn: MUL0940-4 max_entropy: 0 min_confidence: 506.5697326660156
# +++++++++++++++ dialogue per round: [89/99] total round: [0/5] current selected_dialogue_id: pmul1475 +++++++++++++++
# dialogue_turns: 4
# use Least Confidence to select turn
# confidence_list: [260.7415771484375, 170.87448120117188, 153.2530517578125, 154.46533203125]
# selected_turn_id: 2
# min_confidence: 153.2530517578125
# selected turn: PMUL1475-2 max_entropy: 0 min_confidence: 153.2530517578125
# +++++++++++++++ dialogue per round: [90/99] total round: [0/5] current selected_dialogue_id: pmul4690 +++++++++++++++
# dialogue_turns: 10
# use Least Confidence to select turn
# confidence_list: [1578.775390625, 1591.402099609375, 1589.3831787109375, 1308.495361328125, 990.1417236328125, 718.9183959960938, 722.447509765625, 707.8203125, 700.317626953125, 703.0316162109375]
# selected_turn_id: 8
# min_confidence: 700.317626953125
# selected turn: PMUL4690-8 max_entropy: 0 min_confidence: 700.317626953125
# +++++++++++++++ dialogue per round: [91/99] total round: [0/5] current selected_dialogue_id: pmul1638 +++++++++++++++
# dialogue_turns: 10
# use Least Confidence to select turn
# confidence_list: [1507.5943603515625, 1244.405517578125, 1224.958251953125, 1178.00634765625, 1173.74609375, 1128.0955810546875, 1034.2943115234375, 701.8864135742188, 746.6937255859375, 810.86474609375]
# selected_turn_id: 7
# min_confidence: 701.8864135742188
# selected turn: PMUL1638-7 max_entropy: 0 min_confidence: 701.8864135742188
# +++++++++++++++ dialogue per round: [92/99] total round: [0/5] current selected_dialogue_id: ssng0125 +++++++++++++++
# dialogue_turns: 5
# use Least Confidence to select turn
# confidence_list: [651.1024169921875, 547.98388671875, 394.02734375, 346.5648498535156, 343.72406005859375]
# selected_turn_id: 4
# min_confidence: 343.72406005859375
# selected turn: SSNG0125-4 max_entropy: 0 min_confidence: 343.72406005859375
# +++++++++++++++ dialogue per round: [93/99] total round: [0/5] current selected_dialogue_id: mul0284 +++++++++++++++
# dialogue_turns: 7
# use Least Confidence to select turn
# confidence_list: [930.0875244140625, 663.919189453125, 672.979248046875, 445.0602111816406, 433.9274597167969, 825.9889526367188, 860.5454711914062]
# selected_turn_id: 4
# min_confidence: 433.9274597167969
# selected turn: MUL0284-4 max_entropy: 0 min_confidence: 433.9274597167969
# +++++++++++++++ dialogue per round: [94/99] total round: [0/5] current selected_dialogue_id: mul0087 +++++++++++++++
# dialogue_turns: 8
# use Least Confidence to select turn
# confidence_list: [1519.8853759765625, 1494.489501953125, 1309.0120849609375, 1239.97607421875, 939.6448364257812, 1055.134521484375, 762.1690063476562, 787.6463012695312]
# selected_turn_id: 6
# min_confidence: 762.1690063476562
# selected turn: MUL0087-6 max_entropy: 0 min_confidence: 762.1690063476562
# +++++++++++++++ dialogue per round: [95/99] total round: [0/5] current selected_dialogue_id: mul2272 +++++++++++++++
# dialogue_turns: 9
# use Least Confidence to select turn
# confidence_list: [1503.6915283203125, 1508.0220947265625, 1294.110107421875, 1001.7491455078125, 921.363037109375, 687.5875244140625, 706.9585571289062, 817.782470703125, 629.245361328125]
# selected_turn_id: 8
# min_confidence: 629.245361328125
# selected turn: MUL2272-8 max_entropy: 0 min_confidence: 629.245361328125
# +++++++++++++++ dialogue per round: [96/99] total round: [0/5] current selected_dialogue_id: sng01339 +++++++++++++++
# dialogue_turns: 6
# use Least Confidence to select turn
# confidence_list: [488.5648498535156, 323.4922790527344, 325.8821716308594, 319.64642333984375, 303.48065185546875, 298.6520080566406]
# selected_turn_id: 5
# min_confidence: 298.6520080566406
# selected turn: SNG01339-5 max_entropy: 0 min_confidence: 298.6520080566406
# +++++++++++++++ dialogue per round: [97/99] total round: [0/5] current selected_dialogue_id: sng0639 +++++++++++++++
# dialogue_turns: 5
# use Least Confidence to select turn
# confidence_list: [224.06735229492188, 245.92654418945312, 225.5602264404297, 218.73123168945312, 217.47116088867188]
# selected_turn_id: 4
# min_confidence: 217.47116088867188
# selected turn: SNG0639-4 max_entropy: 0 min_confidence: 217.47116088867188
# +++++++++++++++ dialogue per round: [98/99] total round: [0/5] current selected_dialogue_id: pmul2291 +++++++++++++++
# dialogue_turns: 9
# use Least Confidence to select turn
# confidence_list: [691.81494140625, 470.7140197753906, 548.3396606445312, 541.86181640625, 542.16455078125, 528.1488037109375, 345.3780212402344, 345.0300598144531, 347.1695251464844]
# selected_turn_id: 7
# min_confidence: 345.0300598144531
# selected turn: PMUL2291-7 max_entropy: 0 min_confidence: 345.0300598144531
# +++++++++++++++ dialogue per round: [99/99] total round: [0/5] current selected_dialogue_id: mul0015 +++++++++++++++
# dialogue_turns: 9
# use Least Confidence to select turn
# confidence_list: [1273.321533203125, 1550.2813720703125, 1481.165283203125, 1043.8707275390625, 894.51416015625, 879.913330078125, 890.4767456054688, 886.9853515625, 685.8953857421875]
# selected_turn_id: 8
# min_confidence: 685.8953857421875
# selected turn: MUL0015-8 max_entropy: 0 min_confidence: 685.8953857421875
# After round [0/5], selected turn ids are: 100 ['PMUL2369-2' 'PMUL3009-7' 'MUL1236-8' 'MUL1907-5' 'MUL1990-4'
#  'SSNG0035-2' 'MUL2371-2' 'PMUL2709-1' 'PMUL0971-1' 'MUL0872-7'
#  'MUL1439-3' 'PMUL0466-5' 'PMUL2808-9' 'SSNG0009-4' 'PMUL0842-8'
#  'SNG0262-4' 'PMUL3513-13' 'PMUL4536-4' 'MUL2363-7' 'SNG01712-3'
#  'PMUL3833-4' 'MUL1792-5' 'PMUL1564-8' 'PMUL2631-4' 'SNG01384-2'
#  'PMUL0126-7' 'SNG0504-3' 'PMUL2187-9' 'MUL0630-7' 'PMUL4508-1'
#  'PMUL0383-0' 'SNG1151-1' 'SNG02106-5' 'SNG01622-2' 'MUL0766-6'
#  'SSNG0185-2' 'PMUL2967-1' 'SSNG0169-1' 'MUL0930-7' 'PMUL0411-7'
#  'PMUL3616-7' 'PMUL2451-9' 'MUL1063-3' 'MUL0406-4' 'MUL2178-4'
#  'PMUL3155-3' 'PMUL1643-6' 'PMUL2847-2' 'PMUL2976-8' 'PMUL3963-3'
#  'MUL1717-4' 'PMUL1287-4' 'PMUL4412-7' 'PMUL2752-4' 'SSNG0317-5'
#  'PMUL0834-3' 'PMUL1204-6' 'MUL0856-7' 'PMUL0296-11' 'SNG02090-1'
#  'MUL0611-8' 'MUL0502-5' 'SSNG0372-4' 'PMUL3385-2' 'MUL1688-8'
#  'PMUL0050-3' 'PMUL3033-5' 'SNG01771-3' 'PMUL4342-0' 'SNG1264-3'
#  'PMUL4081-5' 'MUL0137-6' 'MUL0254-4' 'WOZ20402-0' 'SNG1332-3' 'MUL2404-4'
#  'MUL0928-4' 'PMUL1850-3' 'PMUL0981-4' 'PMUL3102-6' 'PMUL2439-4'
#  'PMUL4182-6' 'WOZ20519-1' 'MUL2663-1' 'PMUL2099-2' 'PMUL4563-9'
#  'SNG1395-3' 'PMUL2461-11' 'MUL0940-4' 'PMUL1475-2' 'PMUL4690-8'
#  'PMUL1638-7' 'SSNG0125-4' 'MUL0284-4' 'MUL0087-6' 'MUL2272-8'
#  'SNG01339-5' 'SNG0639-4' 'PMUL2291-7' 'MUL0015-8']
# total selected turn ids are: len=100 ['PMUL2369-2', 'PMUL3009-7', 'MUL1236-8', 'MUL1907-5', 'MUL1990-4', 'SSNG0035-2', 'MUL2371-2', 'PMUL2709-1', 'PMUL0971-1', 'MUL0872-7', 'MUL1439-3', 'PMUL0466-5', 'PMUL2808-9', 'SSNG0009-4', 'PMUL0842-8', 'SNG0262-4', 'PMUL3513-13', 'PMUL4536-4', 'MUL2363-7', 'SNG01712-3', 'PMUL3833-4', 'MUL1792-5', 'PMUL1564-8', 'PMUL2631-4', 'SNG01384-2', 'PMUL0126-7', 'SNG0504-3', 'PMUL2187-9', 'MUL0630-7', 'PMUL4508-1', 'PMUL0383-0', 'SNG1151-1', 'SNG02106-5', 'SNG01622-2', 'MUL0766-6', 'SSNG0185-2', 'PMUL2967-1', 'SSNG0169-1', 'MUL0930-7', 'PMUL0411-7', 'PMUL3616-7', 'PMUL2451-9', 'MUL1063-3', 'MUL0406-4', 'MUL2178-4', 'PMUL3155-3', 'PMUL1643-6', 'PMUL2847-2', 'PMUL2976-8', 'PMUL3963-3', 'MUL1717-4', 'PMUL1287-4', 'PMUL4412-7', 'PMUL2752-4', 'SSNG0317-5', 'PMUL0834-3', 'PMUL1204-6', 'MUL0856-7', 'PMUL0296-11', 'SNG02090-1', 'MUL0611-8', 'MUL0502-5', 'SSNG0372-4', 'PMUL3385-2', 'MUL1688-8', 'PMUL0050-3', 'PMUL3033-5', 'SNG01771-3', 'PMUL4342-0', 'SNG1264-3', 'PMUL4081-5', 'MUL0137-6', 'MUL0254-4', 'WOZ20402-0', 'SNG1332-3', 'MUL2404-4', 'MUL0928-4', 'PMUL1850-3', 'PMUL0981-4', 'PMUL3102-6', 'PMUL2439-4', 'PMUL4182-6', 'WOZ20519-1', 'MUL2663-1', 'PMUL2099-2', 'PMUL4563-9', 'SNG1395-3', 'PMUL2461-11', 'MUL0940-4', 'PMUL1475-2', 'PMUL4690-8', 'PMUL1638-7', 'SSNG0125-4', 'MUL0284-4', 'MUL0087-6', 'MUL2272-8', 'SNG01339-5', 'SNG0639-4', 'PMUL2291-7', 'MUL0015-8']
# After a round, train the intermediate model using all selected turns...
# ============= Initializing model =============
# Start loading model...
# loading model from pretrained...
# Initializing Huggingface T5 model...
# Resizing Token Embeddings...
# Model loaded
# ----------
# Use Adafactor Optimizer for Training.
# Specific learning rate.
# ----------
# patience is: 3
# -----------------------------------------
# Start training at epoch 0
# all_data_list: 100
# Overall Number of datapoints is 100 Number of batches is 50
# At epoch 0, total update steps is 50, the total training loss is 1.980459
# ++++++++++++++++++++++++++++++++++++++++++
# -----------------------------------------
# Start training at epoch 1
# all_data_list: 100
# Overall Number of datapoints is 100 Number of batches is 50
# At epoch 1, total update steps is 50, the total training loss is 1.244408
# ++++++++++++++++++++++++++++++++++++++++++
# -----------------------------------------
# Start training at epoch 2
# all_data_list: 100
# Overall Number of datapoints is 100 Number of batches is 50
# At epoch 2, total update steps is 50, the total training loss is 1.066349
# ++++++++++++++++++++++++++++++++++++++++++
# -----------------------------------------
# Start training at epoch 3
# all_data_list: 100
# Overall Number of datapoints is 100 Number of batches is 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-de66e663e819> in <module>
#     143
#     144 # estimator.fit(inputs)
# --> 145 estimator.fit()
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     953         self.jobs.append(self.latest_training_job)
#     954         if wait:
# --> 955             self.latest_training_job.wait(logs=logs)
#     956
#     957     def _compilation_job_name(self):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1954         # If logs are requested, call logs_for_jobs.
#    1955         if logs != "None":
# -> 1956             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1957         else:
#    1958             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3746                 break
#    3747
# -> 3748             time.sleep(poll)
#    3749
#    3750             if state == LogState.JOB_COMPLETE:
#
# KeyboardInterrupt:

# %%
from sagemaker.analytics import TrainingJobAnalytics

analysis = TrainingJobAnalytics(training_job_name=estimator._current_job_name)
df = analysis.dataframe()
df

# %%
trained_model_s3_path = cifar10_estimator.model_data
trained_model_s3_path

# %%
output_s3_path = trained_model_s3_path[trained_model_s3_path.find(base_job_name):trained_model_s3_path.rfind('/')+1] + 'output.tar.gz'
output_s3_path

# %%
f'{prefix}/{output_s3_path}'

# %%
# download the output.tar.gz
sagemaker_session.download_data(path='checkpoints', bucket=bucket, key_prefix=f'{prefix}/{output_s3_path}')

# %%
# list the content of the tar file
# !tar -ztvf checkpoints/output.tar.gz

# %%
# %%time
# Extract the files from output.tar.gz to checkpoints directory
# !tar -zxvf checkpoints/output.tar.gz -C checkpoints

# %%
tensorboard_s3_output_path = cifar10_estimator.latest_job_tensorboard_artifacts_path()
tensorboard_s3_output_path

# %%
# !pip uninstall tensorboard -y

# %%
# version 2.4.1 works
# !pip install tensorboard==2.3.0

# %%
# !AWS_REGION=ap-southeast-2 tensorboard --logdir $tensorboard_s3_output_path

# %% [markdown]
# # Managed Spot Training with a PyTorch Estimator
#
# For Managed Spot Training using a PyTorch Estimator we need to configure two things:
# 1. Enable the `train_use_spot_instances` constructor arg - a simple self-explanatory boolean.
# 2. Set the `train_max_wait` constructor arg - this is an int arg representing the amount of time you are willing to wait for Spot infrastructure to become available. Some instance types are harder to get at Spot prices and you may have to wait longer. You are not charged for time spent waiting for Spot infrastructure to become available, you're only charged for actual compute time spent once Spot instances have been successfully procured.
#
# Normally, a third requirement would also be necessary here - modifying your code to ensure a regular checkpointing cadence - however, PyTorch Estimators already do this, so no changes are necessary here. Checkpointing is highly recommended for Manage Spot Training jobs due to the fact that Spot instances can be interrupted with short notice and using checkpoints to resume from the last interruption ensures you don't lose any progress made before the interruption.
#
# Feel free to toggle the `use_spot_instances` variable to see the effect of running the same job using regular (a.k.a. "On Demand") infrastructure.
#
# Note that `max_wait` can be set if and only if `use_spot_instances` is enabled and **must** be greater than or equal to `max_run`.

# %%
use_spot_instances = True
max_run=600
max_wait = 1200 if use_spot_instances else None

# %% [markdown]
# ## Simulating Spot interruption after 5 epochs
#
# Our training job should run on 10 epochs.
#
# However, we will simulate a situation that after 5 epochs a spot interruption occurred.
#
# The goal is that the checkpointing data will be copied to S3, so when there is a spot capacity available again, the training job can resume from the 6th epoch.
#
# Note the `checkpoint_s3_uri` variable which stores the S3 URI in which to persist checkpoints that the algorithm persists (if any) during training.
#
# The `debugger_hook_config` parameter must be set to `False` to enable checkpoints to be copied to S3 successfully.

# %%
hyperparameters = {'epochs': 5}


spot_estimator = PyTorch(entry_point='source_dir/cifar10.py',
                            role=role,
                            framework_version='1.7.1',
                            py_version='py3',
                            instance_count=1,
                            instance_type='ml.p3.2xlarge',
                            base_job_name='cifar10-pytorch-spot-1',
                            hyperparameters=hyperparameters,
                            checkpoint_s3_uri=checkpoint_s3_path,
                            debugger_hook_config=False,
                            use_spot_instances=use_spot_instances,
                            max_run=max_run,
                            max_wait=max_wait)

spot_estimator.fit(inputs)

# %% [markdown]
# ### Savings
# Towards the end of the job you should see two lines of output printed:
#
# - `Training seconds: X` : This is the actual compute-time your training job spent
# - `Billable seconds: Y` : This is the time you will be billed for after Spot discounting is applied.
#
# If you enabled the `use_spot_instances` var then you should see a notable difference between `X` and `Y` signifying the cost savings you will get for having chosen Managed Spot Training. This should be reflected in an additional line:
# - `Managed Spot Training savings: (1-Y/X)*100 %`

# %% [markdown]
# ### View the job training Checkpoint configuration
# We can now view the Checkpoint configuration from the training job directly in the SageMaker console.
#
# Log into the [SageMaker console](https://console.aws.amazon.com/sagemaker/home), choose the latest training job, and scroll down to the Checkpoint configuration section.
#
# Choose the S3 output path link and you'll be directed to the S3 bucket were checkpointing data is saved.
#
# You can see there is one file there:
#
# ```python
# checkpoint.pth
# ```
#
# This is the checkpoint file that contains the epoch, model state dict, optimizer state dict, and loss.

# %% [markdown]
# ### Continue training after Spot capacity is resumed
#
# Now we simulate a situation where Spot capacity is resumed.
#
# We will start a training job again, this time with 10 epochs.
#
# What we expect is that the tarining job will start from the 6th epoch.
#
# This is done when training job starts. It checks the checkpoint s3 location for checkpoints data. If there are, they are copied to `/opt/ml/checkpoints` on the training conatiner.
#
# In the code you can see the function to load the checkpoints data:
#
# ```python
# def _load_checkpoint(model, optimizer, args):
#     print("--------------------------------------------")
#     print("Checkpoint file found!")
#     print("Loading Checkpoint From: {}".format(args.checkpoint_path + '/checkpoint.pth'))
#     checkpoint = torch.load(args.checkpoint_path + '/checkpoint.pth')
#     model.load_state_dict(checkpoint['model_state_dict'])
#     optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#     epoch_number = checkpoint['epoch']
#     loss = checkpoint['loss']
#     print("Checkpoint File Loaded - epoch_number: {} - loss: {}".format(epoch_number, loss))
#     print('Resuming training from epoch: {}'.format(epoch_number+1))
#     print("--------------------------------------------")
#     return model, optimizer, epoch_number
# ```

# %%
hyperparameters = {'epochs': 10}


spot_estimator = PyTorch(entry_point='source_dir/cifar10.py',
                            role=role,
                            framework_version='1.7.1',
                            py_version='py3',
                            instance_count=1,
                            instance_type='ml.p3.2xlarge',
                            base_job_name='cifar10-pytorch-spot-2',
                            hyperparameters=hyperparameters,
                            checkpoint_s3_uri=checkpoint_s3_path,
                            debugger_hook_config=False,
                            use_spot_instances=use_spot_instances,
                            max_run=max_run,
                            max_wait=max_wait)

spot_estimator.fit(inputs)

# %% [markdown]
# ### Analyze training job logs
#
# Analyzing the training job logs, we can see that now, the training job starts from the 6th epoch.
#
# We can see the output of `_load_checkpoint` function:
#
# ```
# --------------------------------------------
# Checkpoint file found!
# Loading Checkpoint From: /opt/ml/checkpoints/checkpoint.pth
# Checkpoint File Loaded - epoch_number: 5 - loss: 0.8455273509025574
# Resuming training from epoch: 6
# --------------------------------------------
# ```

# %% [markdown]
# ### View the job training Checkpoint configuration after job completed 10 epochs
#
# We can now view the Checkpoint configuration from the training job directly in the SageMaker console.
#
# Log into the [SageMaker console](https://console.aws.amazon.com/sagemaker/home), choose the latest training job, and scroll down to the Checkpoint configuration section.
#
# Choose the S3 output path link and you'll be directed to the S3 bucket were checkpointing data is saved.
#
# You can see there is still that one file there:
#
# ```python
# checkpoint.pth
# ```
#
# You'll be able to see that the date of the checkpoint file was updated to the time of the 2nd Spot training job.

# %% [markdown]
# # Deploy the trained model to prepare for predictions
#
# The deploy() method creates an endpoint which serves prediction requests in real-time.

# %%
from sagemaker.pytorch import PyTorchModel

predictor = spot_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')

# %% [markdown]
# # Invoking the endpoint

# %%
# get some test images
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%4s' % classes[labels[j]] for j in range(4)))

outputs = predictor.predict(images.numpy())

_, predicted = torch.max(torch.from_numpy(np.array(outputs)), 1)

print('Predicted: ', ' '.join('%4s' % classes[predicted[j]]
                              for j in range(4)))

# %% [markdown]
# # Clean-up
#
# To avoid incurring extra charges to your AWS account, let's delete the endpoint we created:

# %%
predictor.delete_endpoint()
